# %% [markdown]
# Array opeations

# %%
import numpy as np

# %%
a1 = np.array([1,2,3, 4, 5])
a2 = np.array([6, 7, 8, 9, 10])
a2
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
a1 + a2
# Out:
# array([ 7,  9, 11, 13, 15])
