# %%
import numpy as np

# %%
Valid Sudoku

# %%
s = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],
    
    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],
    
    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
])

# %%
r = np.sum(s, axis = 1)
for i in r :
    if i != 45:
        print("Sudoku is not valid")
        break
else:
    print("Sodoku is valid for rows")
# Out:
# Sodoku is valid for rows

# %%
c = np.sum(s, axis = 0)
for i in r :
    if i != 45:
        print("Sudoku is not valid")
        break
else:
    print("Sodoku is valid for column")
# Out:
# Sodoku is valid for column

# %%
General Questions

# %%
import numpy as np

# Columns: [Age, Math Marks, Science Marks]
data = np.array([
    [18, 85, 78],   # Student 1
    [19, 92, 88],   # Student 2
    [17, 76, 95],   # Student 3
    [18, 65, 70],   # Student 4
    [20, 90, 85]    # Student 5
])

# %%
#Get the shape of the matrix.

# %%
data.shape
# Out:
# (5, 3)

# %%
#Find the average age of students.

# %%
np.mean(data[:,0])
# Out:
# np.float64(18.4)

# %%
#Extract Math marks of all students.

# %%
#Find the highest Science mark.

# %%
#Get details of the student who scored more than 90 in Math.

# %%
#Increase Math marks of all students by 5.

# %%
#Find how many students are younger than 19.

# %%
#Calculate the average marks in each subject (column-wise mean).

# %%
#Get data of students who scored at least 80 in both subjects.

# %%
#Replace all Science marks < 75 with 0.
