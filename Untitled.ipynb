# %%
print("Hello World!")
# Out:
# Hello World!

# %%
def greeting():
# Out:
#   Cell In[2], line 1
#     def greeting():
#                    ^
# _IncompleteInputError: incomplete input

# %%
def greet():
    print(f"Hello sir how are u")

# %%
greet()
# Out:
# Hello sir how are u

# %%
print("Hello")
# Out:
# Hello
